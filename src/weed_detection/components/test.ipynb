# %%
import csv

# %%
import pandas as pd

# %%
import pandas as pd
df = pd.read_csv("artifacts/data_ingestion/unzipped/v_20260307_192121_5a0b6671da93a189/labels/train_subset0.csv")
print(df.columns.tolist())
print(df.head(2))
# Out:
# ['Filename', 'Label']
#                 Filename  Label
# 0  20171109-175921-2.jpg      5
# 1  20170714-142019-3.jpg      1

# %%
df = pd.read_csv("artifacts/data_ingestion/unzipped/v_20260307_192121_5a0b6671da93a189/labels/labels.csv", sep=",")
df.head()
# Out:
#                 Filename  Label       Species
# 0  20160928-140314-0.jpg      0  Chinee apple
# 1  20160928-140337-0.jpg      0  Chinee apple
# 2  20160928-140731-0.jpg      0  Chinee apple
# 3  20160928-140747-0.jpg      0  Chinee apple
# 4  20160928-141107-0.jpg      0  Chinee apple

# %%
df.head()
# Out:
#                 Filename  Label       Species
# 0  20160928-140314-0.jpg      0  Chinee apple
# 1  20160928-140337-0.jpg      0  Chinee apple
# 2  20160928-140731-0.jpg      0  Chinee apple
# 3  20160928-140747-0.jpg      0  Chinee apple
# 4  20160928-141107-0.jpg      0  Chinee apple

# %%
print(df["Label"].value_counts().sort_index())
# Out:
# Label
# 0    1125
# 1    1064
# 2    1031
# 3    1022
# 4    1062
# 5    1009
# 6    1074
# 7    1016
# 8    9106
# Name: count, dtype: int64

# %%
print(f"\nMin label : {df['Label'].min()}")
print(f"Max label : {df['Label'].max()}")
print(f"Unique    : {sorted(df['Label'].unique())}")
# Out:
# Min label : 0
# Max label : 8
# Unique    : [np.int64(0), np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8)]

# %%
original_df = pd.read_csv("artifacts/data_ingestion/unzipped/v_20260307_192121_5a0b6671da93a189/labels/labels.csv")
print("\nOriginal labels.csv columns:", list(original_df.columns))
Original labels.csv columns: ['Filename', 'Label', 'Species']
# Out:
# Original labels.csv columns: ['Filename', 'Label', 'Species']
